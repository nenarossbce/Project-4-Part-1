# %% [markdown]
# # Prepare Chicago Crime Data for a GitHub Repository

# %% [markdown]
# - Original Notebook Source: https://github.com/coding-dojo-data-science/preparing-chicago-crime-data
# - Updated 11/17/22

# %% [markdown]
# >- This notebook will process a "Crimes - 2001 to Preset.csv" crime file in your Downloads folder and save it as smaller .csv's in a new "Data/Chicago/" folder inside this notebook's folder/repo.

# %% [markdown]
# # INSTRUCTIONS

# %% [markdown]
# - 1) Go to the Chicago Data Portal's page for ["Crimes - 2001 to Preset"](https://data.cityofchicago.org/Public-Safety/Crimes-2001-to-Present/ijzp-q8t2).
#
# - 2) Click on the Export button on the top right and select CSV.
#     - Save the file to your Downloads folder instead of your repository. **The file is too big for a repository.**
#
#
#
# - 3) Wait for the full file to download.
#     - It is very large (over >1.7GB and may take several minutes to fully download.)
#
#
# - 4) Once the download is complete, change `RAW_FILE` variable below to match the filepath to the downloaded file.

# %% [markdown]
# ## 🚨 Set the correct `RAW_FILE` path

# %% [markdown]
# - The cell below will attempt to check your Downloads folder for any file with a name that contains "Crimes_-_2001_to_Present".
#     - If you know the file path already, you can skip the next cell and just manually set the RAW_FILE variable in the following code cell.

# %%
## Run the cell below to attempt to programmatically find your crime file
import os,glob

## Getting the home folder from environment variables
home_folder = os.environ["C:\Users\nena_\Downloads\Crimes_-_2001_to_Present.csv"]
# print("- Your Home Folder is: " + home_folder)

## Check for downloads folder
if 'Downloads' in os.listdir(home_folder):
    
    
    # Print the Downloads folder path
    dl_folder = os.path.abspath(os.path.join(home_folder,'Downloads'))
    print(f"- Your Downloads folder is '{dl_folder}/'\n")
    
    ## checking for crime files using glob
    crime_files = sorted(glob.glob(dl_folder+'/**/Crimes_-_2001_to_Present*',recursive=True))
    
    # If more than 
    if len(crime_files)==1:
        RAW_FILE = crime_files[0]
        
    elif len(crime_files)>1:
        print('[i] The following files were found:')
        
        for i, fname in enumerate(crime_files):
            print(f"\tcrime_files[{i}] = '{fname}'")
        print(f'\n- Please fill in the RAW_FILE variable in the code cell below with the correct filepath.')

else:
    print(f'[!] Could not programmatically find your downloads folder.')
    print('- Try using Finder (on Mac) or File Explorer (Windows) to navigate to your Downloads folder.')
# Out:
# - Your Downloads folder is 'C:\Users\caell\Downloads/'

# %% [markdown]
# <span style="color:red"> **IF THE CODE ABOVE DID NOT FIND YOUR DOWNLOADED FILE, UNCOMMENT AND CHANGE THE `"YOUR FILEPATH HERE"` VARIABLE ONLY IN THE CELL BELOW**

# %%
## Run the cell below to attempt to programmatically find your crime file
import os,glob

# %%
## (Required) MAKE SURE TO CHANGE THIS VARIABLE TO MATCH YOUR LOCAL FILE NAME
RAW_FILE = ("C:\\Users\\nena_\\Downloads\\Crimes_-_2001_to_Present.csv")

# %% [markdown]
# <span style="color:red"> **DO NOT CHANGE ANYTHING IN THE CELL BELOW**

# %%
## DO NOT CHANGE THIS CELL
if RAW_FILE == r"YOUR FILEPATH HERE":
	raise Exception("You must update the RAW_FILE variable in the previous cell to match your local filepath.")
	
RAW_FILE
# Out:
# 'C:\\Users\\nena_\\Downloads\\Crimes_-_2001_to_Present.csv'

# %%
## (Optional) SET THE FOLDER FOR FINAL FILES
OUTPUT_FOLDER = 'Data/Chicago/'
os.makedirs(OUTPUT_FOLDER, exist_ok=True)

# %% [markdown]
# # 🔄 Full Workflow

# %% [markdown]
# - Now that your RAW_FILE variable is set either:
#     - On the toolbar, click on the Kernel menu > "Restart and Run All".
#     - OR click on this cell first, then on the toolbar click on the "Cell" menu > "Run All Below"

# %%
import pandas as pd

chicago_full = pd.read_csv(RAW_FILE)
chicago_full
# Out:
#                ID Case Number                    Date  \
# 0        11037294    JA371270  03/18/2015 12:00:00 PM
# 1        11646293    JC213749  12/20/2018 03:00:00 PM
# 2        11645836    JC212333  05/01/2016 12:25:00 AM
# 3        11645959    JC211511  12/20/2018 04:00:00 PM
# 4        11645601    JC212935  06/01/2014 12:01:00 AM
# ...           ...         ...                     ...
# 7899121  12131776    JD327752  08/10/2020 08:30:00 PM
# 7899122  12082414    JD269218  06/18/2020 09:00:00 PM
# 7899123  12118237    JD311791  07/27/2020 03:02:00 PM
# 7899124  12142591    JD340297  08/14/2020 03:00:00 PM
# 7899125  12002171    JD177406  03/06/2020 02:00:00 PM
#
#                                        Block  IUCR         Primary Type  \
# 0                          0000X W WACKER DR  1153   DECEPTIVE PRACTICE
# 1                       023XX N LOCKWOOD AVE  1154   DECEPTIVE PRACTICE
# 2                        055XX S ROCKWELL ST  1153   DECEPTIVE PRACTICE
# 3                         045XX N ALBANY AVE  2820        OTHER OFFENSE
# 4                        087XX S SANGAMON ST  1153   DECEPTIVE PRACTICE
# ...                                      ...   ...                  ...
# 7899121               066XX S SACRAMENTO AVE  0620             BURGLARY
# 7899122  093XX S DR MARTIN LUTHER KING JR DR  0820                THEFT
# 7899123                      033XX W POLK ST  0486              BATTERY
# 7899124                 023XX W ROSEMONT AVE  0910  MOTOR VEHICLE THEFT
# 7899125                 033XX N LAKEWOOD AVE  1150   DECEPTIVE PRACTICE
#
#                                      Description Location Description  Arrest  \
# 0            FINANCIAL IDENTITY THEFT OVER $ 300                 BANK   False
# 1        FINANCIAL IDENTITY THEFT $300 AND UNDER            APARTMENT   False
# 2            FINANCIAL IDENTITY THEFT OVER $ 300                  NaN   False
# 3                               TELEPHONE THREAT            RESIDENCE   False
# 4            FINANCIAL IDENTITY THEFT OVER $ 300            RESIDENCE   False
# ...                                          ...                  ...     ...
# 7899121                           UNLAWFUL ENTRY            APARTMENT   False
# 7899122                           $500 AND UNDER            RESIDENCE   False
# 7899123                  DOMESTIC BATTERY SIMPLE            APARTMENT   False
# 7899124                               AUTOMOBILE               STREET   False
# 7899125                        CREDIT CARD FRAUD            APARTMENT   False
#
#          Domestic  ...  Ward  Community Area  FBI Code  X Coordinate  \
# 0           False  ...  42.0            32.0        11           NaN
# 1           False  ...  36.0            19.0        11           NaN
# 2           False  ...  15.0            63.0        11           NaN
# 3           False  ...  33.0            14.0       08A           NaN
# 4           False  ...  21.0            71.0        11           NaN
# ...           ...  ...   ...             ...       ...           ...
# 7899121     False  ...  17.0            66.0        05     1157527.0
# 7899122     False  ...   9.0            49.0        06     1180558.0
# 7899123      True  ...  24.0            27.0       08B     1154169.0
# 7899124     False  ...  50.0             2.0        07     1159419.0
# 7899125     False  ...  44.0             6.0        11     1167040.0
#
#         Y Coordinate  Year              Updated On   Latitude  Longitude  \
# 0                NaN  2015  08/01/2017 03:52:26 PM        NaN        NaN
# 1                NaN  2018  04/06/2019 04:04:43 PM        NaN        NaN
# 2                NaN  2016  04/06/2019 04:04:43 PM        NaN        NaN
# 3                NaN  2018  04/06/2019 04:04:43 PM        NaN        NaN
# 4                NaN  2014  04/06/2019 04:04:43 PM        NaN        NaN
# ...              ...   ...                     ...        ...        ...
# 7899121    1860392.0  2020  08/17/2020 03:41:32 PM  41.772671 -87.698104
# 7899122    1843036.0  2020  06/25/2020 03:41:40 PM  41.724546 -87.614211
# 7899123    1896171.0  2020  08/03/2020 03:41:51 PM  41.870921 -87.709461
# 7899124    1941765.0  2020  08/26/2020 03:40:41 PM  41.995927 -87.688929
# 7899125    1922212.0  2020  03/13/2020 03:41:29 PM  41.942112 -87.661459
#
#                               Location
# 0                                  NaN
# 1                                  NaN
# 2                                  NaN
# 3                                  NaN
# 4                                  NaN
# ...                                ...
# 7899121  (41.772671069, -87.698104059)
# 7899122  (41.724546436, -87.614210743)
# 7899123  (41.870920735, -87.709461362)
# 7899124  (41.995927389, -87.688928533)
# 7899125  (41.942112495, -87.661458579)
#
# [7899126 rows x 22 columns]

# %%
# this cell can take up to 1 min to run
date_format = "%m/%d/%Y %H:%M:%S %p"

chicago_full['Datetime'] = pd.to_datetime(chicago_full['Date'], format=date_format)
chicago_full = chicago_full.sort_values('Datetime')
chicago_full
# Out:
#                ID Case Number                    Date  \
# 2098309   1314713     G001044  01/01/2001 01:00:00 PM
# 2232824   1310782     G001256  01/01/2001 01:00:00 PM
# 1369108   5462733    HN290220  01/01/2001 01:00:00 AM
# 2161692   1310610     G000911  01/01/2001 01:00:00 AM
# 2104120   1330412     G026686  01/01/2001 01:00:00 AM
# ...           ...         ...                     ...
# 82615    13217707    JG432850  09/20/2023 12:00:00 AM
# 82669    13223000    JG439107  09/20/2023 12:00:00 AM
# 81648    13216445    JG431288  09/20/2023 12:00:00 AM
# 81022    13217710    JG432840  09/20/2023 12:00:00 AM
# 80859    13217646    JG432785  09/20/2023 12:00:00 AM
#
#                             Block  IUCR                Primary Type  \
# 2098309        017XX W AUGUSTA BV  0520                     ASSAULT
# 2232824            008XX W 115 ST  0910         MOTOR VEHICLE THEFT
# 1369108       058XX S INDIANA AVE  1752  OFFENSE INVOLVING CHILDREN
# 2161692       022XX W CORNELIA AV  1320             CRIMINAL DAMAGE
# 2104120        019XX N HALSTED ST  0820                       THEFT
# ...                           ...   ...                         ...
# 82615          028XX W AINSLIE ST  1780  OFFENSE INVOLVING CHILDREN
# 82669          085XX W HIGGINS RD  1320             CRIMINAL DAMAGE
# 81648       080XX S WENTWORTH AVE  0486                     BATTERY
# 81022          085XX W HIGGINS RD  1320             CRIMINAL DAMAGE
# 80859    101XX S INDIANAPOLIS AVE  0810                       THEFT
#
#                             Description            Location Description  \
# 2098309  AGGRAVATED:KNIFE/CUTTING INSTR                       RESIDENCE
# 2232824                      AUTOMOBILE  PARKING LOT/GARAGE(NON.RESID.)
# 1369108   AGG CRIM SEX ABUSE FAM MEMBER                       RESIDENCE
# 2161692                      TO VEHICLE                          STREET
# 2104120                  $500 AND UNDER             TAVERN/LIQUOR STORE
# ...                                 ...                             ...
# 82615                     OTHER OFFENSE                       RESIDENCE
# 82669                        TO VEHICLE                   HOTEL / MOTEL
# 81648           DOMESTIC BATTERY SIMPLE                       RESIDENCE
# 81022                        TO VEHICLE                   HOTEL / MOTEL
# 80859                         OVER $500                 OTHER (SPECIFY)
#
#          Arrest  Domestic  ...  Community Area  FBI Code  X Coordinate  \
# 2098309    True      True  ...             NaN       04A     1164232.0
# 2232824   False     False  ...             NaN        07     1172806.0
# 1369108   False      True  ...            40.0        20     1178551.0
# 2161692   False     False  ...             NaN        14     1160786.0
# 2104120   False     False  ...             NaN        06     1170604.0
# ...         ...       ...  ...             ...       ...           ...
# 82615     False      True  ...             4.0        20     1156364.0
# 82669     False     False  ...            76.0        14     1118169.0
# 81648     False      True  ...            44.0       08B     1176386.0
# 81022     False     False  ...            76.0        14     1118169.0
# 80859     False     False  ...            52.0        06     1202619.0
#
#          Y Coordinate  Year              Updated On   Latitude  Longitude  \
# 2098309     1906669.0  2001  08/17/2015 03:03:40 PM  41.899521 -87.672220
# 2232824     1828626.0  2001  08/17/2015 03:03:40 PM  41.685177 -87.643029
# 1369108     1866538.0  2001  04/25/2007 05:57:12 AM  41.789084 -87.620849
# 2161692     1923163.0  2001  08/17/2015 03:03:40 PM  41.944854 -87.684418
# 2104120     1913228.0  2001  08/17/2015 03:03:40 PM  41.917383 -87.648623
# ...               ...   ...                     ...        ...        ...
# 82615       1932553.0  2023  09/27/2023 03:43:25 PM  41.970712 -87.700417
# 82669       1938234.0  2023  09/27/2023 03:43:25 PM  41.986989 -87.840746
# 81648       1851621.0  2023  09/27/2023 03:43:25 PM  41.748199 -87.629235
# 81022       1938234.0  2023  09/27/2023 03:43:25 PM  41.986989 -87.840746
# 80859       1838376.0  2023  09/27/2023 03:43:25 PM  41.711225 -87.533562
#
#                               Location            Datetime
# 2098309  (41.899521453, -87.672219588) 2001-01-01 01:00:00
# 2232824  (41.685177431, -87.643029232) 2001-01-01 01:00:00
# 1369108  (41.789084341, -87.620849345) 2001-01-01 01:00:00
# 2161692  (41.944854306, -87.684418276) 2001-01-01 01:00:00
# 2104120  (41.917382588, -87.648623098) 2001-01-01 01:00:00
# ...                                ...                 ...
# 82615     (41.97071175, -87.700416882) 2023-09-20 12:00:00
# 82669    (41.986989467, -87.840745861) 2023-09-20 12:00:00
# 81648    (41.748199389, -87.629235372) 2023-09-20 12:00:00
# 81022    (41.986989467, -87.840745861) 2023-09-20 12:00:00
# 80859     (41.71122491, -87.533561854) 2023-09-20 12:00:00
#
# [7899126 rows x 23 columns]

# %% [markdown]
# ## Separate the Full Dataset by Years

# %%
chicago_full['Datetime'].dt.year
# Out:
# 2098309    2001
# 2232824    2001
# 1369108    2001
# 2161692    2001
# 2104120    2001
#            ...
# 82615      2023
# 82669      2023
# 81648      2023
# 81022      2023
# 80859      2023
# Name: Datetime, Length: 7899126, dtype: int64

# %%
# save the years for every crime
chicago_full["Year"] = chicago_full['Datetime'].dt.year.astype(str)
chicago_full["Year"].value_counts()
# Out:
# 2002    486807
# 2001    485888
# 2003    475985
# 2004    469423
# 2005    453774
# 2006    448178
# 2007    437090
# 2008    427184
# 2009    392827
# 2010    370517
# 2011    351993
# 2012    336322
# 2013    307540
# 2014    275792
# 2016    269834
# 2017    269109
# 2018    268912
# 2015    264793
# 2019    261352
# 2022    238947
# 2020    212220
# 2021    208870
# 2023    185769
# Name: Year, dtype: int64

# %%
## Dropping unneeded columns to reduce file size
drop_cols = ["X Coordinate","Y Coordinate", "Community Area","FBI Code",
             "Case Number","Updated On",'Block','Location','IUCR']

# %%
# save final df
chicago_final = chicago_full.drop(columns=drop_cols)
chicago_final = chicago_final.set_index('Datetime')
chicago_final
# Out:
#                            ID                    Date  \
# Datetime
# 2001-01-01 01:00:00   1314713  01/01/2001 01:00:00 PM
# 2001-01-01 01:00:00   1310782  01/01/2001 01:00:00 PM
# 2001-01-01 01:00:00   5462733  01/01/2001 01:00:00 AM
# 2001-01-01 01:00:00   1310610  01/01/2001 01:00:00 AM
# 2001-01-01 01:00:00   1330412  01/01/2001 01:00:00 AM
# ...                       ...                     ...
# 2023-09-20 12:00:00  13217707  09/20/2023 12:00:00 AM
# 2023-09-20 12:00:00  13223000  09/20/2023 12:00:00 AM
# 2023-09-20 12:00:00  13216445  09/20/2023 12:00:00 AM
# 2023-09-20 12:00:00  13217710  09/20/2023 12:00:00 AM
# 2023-09-20 12:00:00  13217646  09/20/2023 12:00:00 AM
#
#                                    Primary Type  \
# Datetime
# 2001-01-01 01:00:00                     ASSAULT
# 2001-01-01 01:00:00         MOTOR VEHICLE THEFT
# 2001-01-01 01:00:00  OFFENSE INVOLVING CHILDREN
# 2001-01-01 01:00:00             CRIMINAL DAMAGE
# 2001-01-01 01:00:00                       THEFT
# ...                                         ...
# 2023-09-20 12:00:00  OFFENSE INVOLVING CHILDREN
# 2023-09-20 12:00:00             CRIMINAL DAMAGE
# 2023-09-20 12:00:00                     BATTERY
# 2023-09-20 12:00:00             CRIMINAL DAMAGE
# 2023-09-20 12:00:00                       THEFT
#
#                                         Description  \
# Datetime
# 2001-01-01 01:00:00  AGGRAVATED:KNIFE/CUTTING INSTR
# 2001-01-01 01:00:00                      AUTOMOBILE
# 2001-01-01 01:00:00   AGG CRIM SEX ABUSE FAM MEMBER
# 2001-01-01 01:00:00                      TO VEHICLE
# 2001-01-01 01:00:00                  $500 AND UNDER
# ...                                             ...
# 2023-09-20 12:00:00                   OTHER OFFENSE
# 2023-09-20 12:00:00                      TO VEHICLE
# 2023-09-20 12:00:00         DOMESTIC BATTERY SIMPLE
# 2023-09-20 12:00:00                      TO VEHICLE
# 2023-09-20 12:00:00                       OVER $500
#
#                                Location Description  Arrest  Domestic  Beat  \
# Datetime
# 2001-01-01 01:00:00                       RESIDENCE    True      True  1322
# 2001-01-01 01:00:00  PARKING LOT/GARAGE(NON.RESID.)   False     False  2234
# 2001-01-01 01:00:00                       RESIDENCE   False      True   233
# 2001-01-01 01:00:00                          STREET   False     False  1913
# 2001-01-01 01:00:00             TAVERN/LIQUOR STORE   False     False  1813
# ...                                             ...     ...       ...   ...
# 2023-09-20 12:00:00                       RESIDENCE   False      True  2031
# 2023-09-20 12:00:00                   HOTEL / MOTEL   False     False  1614
# 2023-09-20 12:00:00                       RESIDENCE   False      True   623
# 2023-09-20 12:00:00                   HOTEL / MOTEL   False     False  1614
# 2023-09-20 12:00:00                 OTHER (SPECIFY)   False     False   432
#
#                      District  Ward  Year   Latitude  Longitude
# Datetime
# 2001-01-01 01:00:00      12.0   NaN  2001  41.899521 -87.672220
# 2001-01-01 01:00:00      22.0   NaN  2001  41.685177 -87.643029
# 2001-01-01 01:00:00       2.0  20.0  2001  41.789084 -87.620849
# 2001-01-01 01:00:00      19.0   NaN  2001  41.944854 -87.684418
# 2001-01-01 01:00:00      18.0   NaN  2001  41.917383 -87.648623
# ...                       ...   ...   ...        ...        ...
# 2023-09-20 12:00:00      20.0  40.0  2023  41.970712 -87.700417
# 2023-09-20 12:00:00      16.0  41.0  2023  41.986989 -87.840746
# 2023-09-20 12:00:00       6.0  17.0  2023  41.748199 -87.629235
# 2023-09-20 12:00:00      16.0  41.0  2023  41.986989 -87.840746
# 2023-09-20 12:00:00       4.0  10.0  2023  41.711225 -87.533562
#
# [7899126 rows x 13 columns]

# %%
# unique # of year bins
year_bins = chicago_final['Year'].astype(str).unique()
year_bins
# Out:
# array(['2001', '2002', '2003', '2004', '2005', '2006', '2007', '2008',
#        '2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016',
#        '2017', '2018', '2019', '2020', '2021', '2022', '2023'],
#       dtype=object)

# %%
FINAL_DROP = ['Year']

# %%
## set save location 

os.makedirs(OUTPUT_FOLDER, exist_ok=True)
print(f"[i] Saving .csv's to {OUTPUT_FOLDER}")
## loop through years
for year in year_bins:
    
    ## save temp slices of dfs to save.
    temp_df = chicago_final.loc[year]
    temp_df = temp_df.sort_index()
    temp_df = temp_df.reset_index(drop=True)
    temp_df = temp_df.drop(columns=FINAL_DROP)

    # save as csv to output folder
    fname_temp = f"{OUTPUT_FOLDER}Chicago-Crime_{year}.csv"#.gz
    temp_df.to_csv(fname_temp,index=False)

    print(f"- Succesfully saved {fname_temp}")
# Out:
# [i] Saving .csv's to Data/Chicago/
# - Succesfully saved Data/Chicago/Chicago-Crime_2001.csv
# - Succesfully saved Data/Chicago/Chicago-Crime_2002.csv
# - Succesfully saved Data/Chicago/Chicago-Crime_2003.csv
# - Succesfully saved Data/Chicago/Chicago-Crime_2004.csv
# - Succesfully saved Data/Chicago/Chicago-Crime_2005.csv
# - Succesfully saved Data/Chicago/Chicago-Crime_2006.csv
# - Succesfully saved Data/Chicago/Chicago-Crime_2007.csv
# - Succesfully saved Data/Chicago/Chicago-Crime_2008.csv
# - Succesfully saved Data/Chicago/Chicago-Crime_2009.csv
# - Succesfully saved Data/Chicago/Chicago-Crime_2010.csv
# - Succesfully saved Data/Chicago/Chicago-Crime_2011.csv
# - Succesfully saved Data/Chicago/Chicago-Crime_2012.csv
# - Succesfully saved Data/Chicago/Chicago-Crime_2013.csv
# - Succesfully saved Data/Chicago/Chicago-Crime_2014.csv
# - Succesfully saved Data/Chicago/Chicago-Crime_2015.csv
# - Succesfully saved Data/Chicago/Chicago-Crime_2016.csv
# - Succesfully saved Data/Chicago/Chicago-Crime_2017.csv
# - Succesfully saved Data/Chicago/Chicago-Crime_2018.csv
# - Succesfully saved Data/Chicago/Chicago-Crime_2019.csv
# - Succesfully saved Data/Chicago/Chicago-Crime_2020.csv
# - Succesfully saved Data/Chicago/Chicago-Crime_2021.csv
# - Succesfully saved Data/Chicago/Chicago-Crime_2022.csv
# - Succesfully saved Data/Chicago/Chicago-Crime_2023.csv

# %%
saved_files = sorted(glob.glob(OUTPUT_FOLDER+'*.*csv'))
saved_files
# Out:
# ['Data/Chicago\\Chicago-Crime_2001.csv',
#  'Data/Chicago\\Chicago-Crime_2002.csv',
#  'Data/Chicago\\Chicago-Crime_2003.csv',
#  'Data/Chicago\\Chicago-Crime_2004.csv',
#  'Data/Chicago\\Chicago-Crime_2005.csv',
#  'Data/Chicago\\Chicago-Crime_2006.csv',
#  'Data/Chicago\\Chicago-Crime_2007.csv',
#  'Data/Chicago\\Chicago-Crime_2008.csv',
#  'Data/Chicago\\Chicago-Crime_2009.csv',
#  'Data/Chicago\\Chicago-Crime_2010.csv',
#  'Data/Chicago\\Chicago-Crime_2011.csv',
#  'Data/Chicago\\Chicago-Crime_2012.csv',
#  'Data/Chicago\\Chicago-Crime_2013.csv',
#  'Data/Chicago\\Chicago-Crime_2014.csv',
#  'Data/Chicago\\Chicago-Crime_2015.csv',
#  'Data/Chicago\\Chicago-Crime_2016.csv',
#  'Data/Chicago\\Chicago-Crime_2017.csv',
#  'Data/Chicago\\Chicago-Crime_2018.csv',
#  'Data/Chicago\\Chicago-Crime_2019.csv',
#  'Data/Chicago\\Chicago-Crime_2020.csv',
#  'Data/Chicago\\Chicago-Crime_2021.csv',
#  'Data/Chicago\\Chicago-Crime_2022.csv',
#  'Data/Chicago\\Chicago-Crime_2023.csv']

# %%
## create a README.txt for the zip files
readme = """Source URL: 
- https://data.cityofchicago.org/Public-Safety/Crimes-2001-to-Present/ijzp-q8t2
- Filtered for years 2000-Present.

Downloaded 07/18/2022
- Files are split into 1 year per file.

EXAMPLE USAGE:
>> import glob
>> import pandas as pd
>> folder = "Data/Chicago/"
>> crime_files = sorted(glob.glob(folder+"*.csv"))
>> df = pd.concat([pd.read_csv(f) for f in crime_files])
"""
print(readme)


with open(f"{OUTPUT_FOLDER}README.txt",'w') as f:
    f.write(readme)
# Out:
# Source URL:
# - https://data.cityofchicago.org/Public-Safety/Crimes-2001-to-Present/ijzp-q8t2
# - Filtered for years 2000-Present.
#
# Downloaded 07/18/2022
# - Files are split into 1 year per file.
#
# EXAMPLE USAGE:
# >> import glob
# >> import pandas as pd
# >> folder = "Data/Chicago/"
# >> crime_files = sorted(glob.glob(folder+"*.csv"))
# >> df = pd.concat([pd.read_csv(f) for f in crime_files])

# %% [markdown]
# ## Confirmation

# %% [markdown]
# - Follow the example usage above to test if your files were created successfully.

# %%
# get list of files from folder
crime_files = sorted(glob.glob(OUTPUT_FOLDER+"*.csv"))
df = pd.concat([pd.read_csv(f) for f in crime_files])
df
# Out:
#               ID                    Date                Primary Type  \
# 0        1314713  01/01/2001 01:00:00 PM                     ASSAULT
# 1        1310782  01/01/2001 01:00:00 PM         MOTOR VEHICLE THEFT
# 2        5462733  01/01/2001 01:00:00 AM  OFFENSE INVOLVING CHILDREN
# 3        1310610  01/01/2001 01:00:00 AM             CRIMINAL DAMAGE
# 4        1330412  01/01/2001 01:00:00 AM                       THEFT
# ...          ...                     ...                         ...
# 185764  13217707  09/20/2023 12:00:00 AM  OFFENSE INVOLVING CHILDREN
# 185765  13223000  09/20/2023 12:00:00 AM             CRIMINAL DAMAGE
# 185766  13216445  09/20/2023 12:00:00 AM                     BATTERY
# 185767  13217710  09/20/2023 12:00:00 AM             CRIMINAL DAMAGE
# 185768  13217646  09/20/2023 12:00:00 AM                       THEFT
#
#                            Description            Location Description  \
# 0       AGGRAVATED:KNIFE/CUTTING INSTR                       RESIDENCE
# 1                           AUTOMOBILE  PARKING LOT/GARAGE(NON.RESID.)
# 2        AGG CRIM SEX ABUSE FAM MEMBER                       RESIDENCE
# 3                           TO VEHICLE                          STREET
# 4                       $500 AND UNDER             TAVERN/LIQUOR STORE
# ...                                ...                             ...
# 185764                   OTHER OFFENSE                       RESIDENCE
# 185765                      TO VEHICLE                   HOTEL / MOTEL
# 185766         DOMESTIC BATTERY SIMPLE                       RESIDENCE
# 185767                      TO VEHICLE                   HOTEL / MOTEL
# 185768                       OVER $500                 OTHER (SPECIFY)
#
#         Arrest  Domestic  Beat  District  Ward   Latitude  Longitude
# 0         True      True  1322      12.0   NaN  41.899521 -87.672220
# 1        False     False  2234      22.0   NaN  41.685177 -87.643029
# 2        False      True   233       2.0  20.0  41.789084 -87.620849
# 3        False     False  1913      19.0   NaN  41.944854 -87.684418
# 4        False     False  1813      18.0   NaN  41.917383 -87.648623
# ...        ...       ...   ...       ...   ...        ...        ...
# 185764   False      True  2031      20.0  40.0  41.970712 -87.700417
# 185765   False     False  1614      16.0  41.0  41.986989 -87.840746
# 185766   False      True   623       6.0  17.0  41.748199 -87.629235
# 185767   False     False  1614      16.0  41.0  41.986989 -87.840746
# 185768   False     False   432       4.0  10.0  41.711225 -87.533562
#
# [7899126 rows x 12 columns]

# %%
years = df['Date'].map(lambda x: x.split()[0].split('/')[-1])
years.value_counts().sort_index()
# Out:
# 2001    485888
# 2002    486807
# 2003    475985
# 2004    469423
# 2005    453774
# 2006    448178
# 2007    437090
# 2008    427184
# 2009    392827
# 2010    370517
# 2011    351993
# 2012    336322
# 2013    307540
# 2014    275792
# 2015    264793
# 2016    269834
# 2017    269109
# 2018    268912
# 2019    261352
# 2020    212220
# 2021    208870
# 2022    238947
# 2023    185769
# Name: Date, dtype: int64

# %% [markdown]
# ## Summary

# %% [markdown]
# - The chicago crime dataset has now been saved to your repository as csv files.
# - You should save your notebook, commit your work and push to GitHub using GitHub desktop.
